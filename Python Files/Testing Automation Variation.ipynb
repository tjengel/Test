# %%
import pandas
from ggplot import *
test = pandas.read_csv('/Users/tylerengel/Downloads/search-results-2016-11-23T10-51-13.211-0800.csv')

# Describing data
test.dtypes
test.describe()
# Out:
#        messagetimems     duration
# count   8.677000e+03  8677.000000
# mean    1.479520e+12    41.576611
# std     1.782848e+08    74.269430
# min     1.479322e+12     0.000000
# 25%     1.479393e+12    15.498700
# 50%     1.479433e+12    25.699878
# 75%     1.479741e+12    40.319513
# max     1.479921e+12  2110.498566

# %%
# Describing grouped by test name
grouped = test.groupby('test_name')
grouped['duration'].describe()

# %%
# Plotting all the tests
ggplot(test, aes(x='messagetimems', y='duration', color='test_name')) + geom_line()
# Out:
# <ggplot: (276232901)>

# %%
# Creating smaller dataframes to test with
new_df = test.query('test_name == "test_feed_view_highlight"')
new_df2 = test.query('test_name == "test_v3_uploader_practice_video"')

# %%
ggplot(new_df2, aes(x='messagetimems', y='duration', color='test_name')) + geom_point()
# Out:
# <ggplot: (275755745)>
